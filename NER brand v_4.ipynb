# %%
import json
import pandas as pd
import numpy as np
import string
import spacy
import warnings
warnings.filterwarnings("ignore")
from spacy.matcher import Matcher

# %%
def get_brand(data):
    nlp = spacy.load('en_core_web_sm')
    brand_patterns = [
        {"LOWER":"agrale","OP":"?"},
        {"LOWER":"aiways","OP":"?"},
        {"LOWER":"ankai","OP":"?"},
        {"LOWER":"arrival","OP":"?"},
        {"LOWER":"ashok leyland","OP":"?"},
        {"LOWER":"aston martin","OP":"?"},
        {"LOWER":"zaz","OP":"?"},
        {"LOWER":"arcfox","OP":"?"},
        {"LOWER":"beijing","OP":"?"},
        {"LOWER":"beijing auto","OP":"?"},
        {"LOWER":"bisu","OP":"?"},
        {"LOWER":"changhe","OP":"?"},
        {"LOWER":"foton","OP":"?"},
        {"LOWER":"gratour","OP":"?"},
        {"LOWER":"huansu","OP":"?"},
        {"LOWER":"senova","OP":"?"},
        {"LOWER":"weiwang","OP":"?"},
        {"LOWER":"bjev","OP":"?"},
        {"LOWER":"daoda","OP":"?"},
        {"LOWER":"ideal","OP":"?"},
        {"LOWER":"baoneng","OP":"?"},
        {"LOWER":"bmw","OP":"?"},
        {"LOWER":"mini","OP":"?"},
        {"LOWER":"rolls-royce","OP":"?"},
        {"LOWER":"zinoro","OP":"?"},
        {"LOWER":"bollore","OP":"?"},
        {"LOWER":"borgward","OP":"?"},
        {"LOWER":"brilliance","OP":"?"},
        {"LOWER":"jinbei","OP":"?"},
        {"LOWER":"swm","OP":"?"},
        {"LOWER":"huasong","OP":"?"},
        {"LOWER":"zhonghua","OP":"?"},
        {"LOWER":"byd","OP":"?"},
        {"LOWER":"denza","OP":"?"},
        {"LOWER":"canoo","OP":"?"},
        {"LOWER":"caterham","OP":"?"},
        {"LOWER":"changan","OP":"?"},
        {"LOWER":"changhe","OP":"?"},
        {"LOWER":"kaicheng","OP":"?"},
        {"LOWER":"ossan","OP":"?"},
        {"LOWER":"changfeng-yangzi","OP":"?"},
        {"LOWER":"leopaard","OP":"?"},
        #{"LOWER":"event","OP":"?"},
        {"LOWER":"shudu","OP":"?"},
        {"LOWER":"baoneng","OP":"?"},
        {"LOWER":"chery","OP":"?"},
        {"LOWER":"cowin","OP":"?"},
        {"LOWER":"exeed","OP":"?"},
        {"LOWER":"jetour","OP":"?"},
        {"LOWER":"karry","OP":"?"},
        {"LOWER":"qoros","OP":"?"},
        {"LOWER":"rely","OP":"?"},
        {"LOWER":"wanda","OP":"?"},
        {"LOWER":"china first tractor","OP":"?"},
        {"LOWER":"china motor","OP":"?"},
        {"LOWER":"iveco","OP":"?"},
        {"LOWER":"chengdu wangpai","OP":"?"},
        {"LOWER":"huanghe","OP":"?"},
        {"LOWER":"crrc","OP":"?"},
        {"LOWER":"mercedes-benz","OP":"?"},
        {"LOWER":"benz","OP":"?"},
        {"LOWER":"mercedes","OP":"?"},
        {"LOWER":"mitsubishi fuso","OP":"?"},
        #{"LOWER":"smart","OP":"?"},
        {"LOWER":"freightliner","OP":"?"},
        {"LOWER":"streetscooter","OP":"?"},
        {"LOWER":"dfsk","OP":"?"},
        {"LOWER":"dongfeng","OP":"?"},
        {"LOWER":"fukang","OP":"?"},
        {"LOWER":"ruichi","OP":"?"},
        {"LOWER":"seres","OP":"?"},
        {"LOWER":"voyah","OP":"?"},
        {"LOWER":"dorcen","OP":"?"},
        {"LOWER":"dreamedge","OP":"?"},
        {"LOWER":"eicher motor","OP":"?"},
        {"LOWER":"hengchi","OP":"?"},
        {"LOWER":"besturn","OP":"?"},
        {"LOWER":"faw","OP":"?"},
        {"LOWER":"hongqi","OP":"?"},
        {"LOWER":"changjiang","OP":"?"},
        {"LOWER":"ferrari","OP":"?"},
        {"LOWER":"fisker","OP":"?"},
        {"LOWER":"byton","OP":"?"},
        {"LOWER":"foday","OP":"?"},
        {"LOWER":"fomm","OP":"?"},
        {"LOWER":"force motors","OP":"?"},
        {"LOWER":"ford","OP":"?"},
        {"LOWER":"lincoln","OP":"?"},
        {"LOWER":"troller","OP":"?"},
        {"LOWER":"metrocab","OP":"?"},
        {"LOWER":"forta","OP":"?"},
        {"LOWER":"qiteng","OP":"?"},
        {"LOWER":"yudo","OP":"?"},
        {"LOWER":"aion","OP":"?"},
        {"LOWER":"hycan","OP":"?"},
        {"LOWER":"mitsubishi","OP":"?"},
        {"LOWER":"gaz","OP":"?"},
        {"LOWER":"geely","OP":"?"},
        {"LOWER":"geometry","OP":"?"},
        {"LOWER":"levc","OP":"?"},
        {"LOWER":"lotus","OP":"?"},
        {"LOWER":"lynk&co","OP":"?"},
        {"LOWER":"maple","OP":"?"},
        {"LOWER":"polestar","OP":"?"},
        {"LOWER":"volvo","OP":"?"},
        {"LOWER":"yuancheng","OP":"?"},
        {"LOWER":"zeekr","OP":"?"},
        {"LOWER":"englon","OP":"?"},
        {"LOWER":"gleagle","OP":"?"},
        {"LOWER":"zhidou","OP":"?"},
        {"LOWER":"brightdrop","OP":"?"},
        {"LOWER":"buick","OP":"?"},
        {"LOWER":"cadillac","OP":"?"},
        {"LOWER":"chevrolet","OP":"?"},
        {"LOWER":"daewoo","OP":"?"},
        {"LOWER":"gmc","OP":"?"},
        {"LOWER":"cruise","OP":"?"},
        {"LOWER":"holden","OP":"?"},
        {"LOWER":"glm","OP":"?"},
        {"LOWER":"bmw-gw","OP":"?"},
        {"LOWER":"great wall","OP":"?"},
        {"LOWER":"haval","OP":"?"},
        {"LOWER":"ora","OP":"?"},
        {"LOWER":"poer","OP":"?"},
        #{"LOWER":"tank","OP":"?"},
        {"LOWER":"wey","OP":"?"},
        {"LOWER":"green wheel","OP":"?"},
        {"LOWER":"guangtong","OP":"?"},
        {"LOWER":"guangzhou auto","OP":"?"},
        {"LOWER":"guilin bus","OP":"?"},
        {"LOWER":"space","OP":"?"},
        {"LOWER":"victory","OP":"?"},
        {"LOWER":"haima","OP":"?"},
        {"LOWER":"hanteng","OP":"?"},
        {"LOWER":"hawtai","OP":"?"},
        {"LOWER":"shandong kaima","OP":"?"},
        {"LOWER":"acura","OP":"?"},
        {"LOWER":"ciimo","OP":"?"},
        {"LOWER":"everus","OP":"?"},
        {"LOWER":"honda","OP":"?"},
        {"LOWER":"neta","OP":"?"},
        {"LOWER":"sanhuan","OP":"?"},
        {"LOWER":"wanshan","OP":"?"},
        {"LOWER":"hiphi","OP":"?"},
        {"LOWER":"genesis","OP":"?"},
        {"LOWER":"hyundai","OP":"?"},
        {"LOWER":"kia","OP":"?"},
        {"LOWER":"horki","OP":"?"},
        {"LOWER":"icm","OP":"?"},
        {"LOWER":"ineos","OP":"?"},
        {"LOWER":"iran khodro","OP":"?"},
        {"LOWER":"peugeot (ikco)","OP":"?"},
        {"LOWER":"isuzu","OP":"?"},
        {"LOWER":"lingbox","OP":"?"},
        {"LOWER":"jac","OP":"?"},
        {"LOWER":"jianghuai","OP":"?"},
        {"LOWER":"refine","OP":"?"},
        {"LOWER":"sehol","OP":"?"},
        {"LOWER":"sol","OP":"?"},
        {"LOWER":"jiangling","OP":"?"},
        {"LOWER":"jmev","OP":"?"},
        {"LOWER":"landwind","OP":"?"},
        {"LOWER":"lushan","OP":"?"},
        {"LOWER":"jihai","OP":"?"},
        {"LOWER":"joylong","OP":"?"},
        {"LOWER":"karma","OP":"?"},
        {"LOWER":"karsan","OP":"?"},
        {"LOWER":"golden dragon","OP":"?"},
        {"LOWER":"king long","OP":"?"},
        {"LOWER":"skywell","OP":"?"},
        {"LOWER":"skyworth","OP":"?"},
        {"LOWER":"leapmotor","OP":"?"},
        {"LOWER":"levdeo","OP":"?"},
        {"LOWER":"lifan","OP":"?"},
        {"LOWER":"linking","OP":"?"},
        {"LOWER":"linktour","OP":"?"},
        {"LOWER":"li","OP":"?"},
        {"LOWER":"lordstown","OP":"?"},
        {"LOWER":"lucid","OP":"?"},
        {"LOWER":"mahindra","OP":"?"},
        {"LOWER":"ssangyong","OP":"?"},
        {"LOWER":"volare","OP":"?"},
        {"LOWER":"mazda","OP":"?"},
        {"LOWER":"mclaren","OP":"?"},
        {"LOWER":"morgan","OP":"?"},
        {"LOWER":"aurus","OP":"?"},
        {"LOWER":"nio","OP":"?"},
        {"LOWER":"perodua","OP":"?"},
        {"LOWER":"piaggio","OP":"?"},
        {"LOWER":"premier","OP":"?"},
        {"LOWER":"proton","OP":"?"},
        {"LOWER":"qingling","OP":"?"},
        {"LOWER":"alpine","OP":"?"},
        {"LOWER":"dacia","OP":"?"},
        {"LOWER":"datsun","OP":"?"},
        {"LOWER":"infiniti","OP":"?"},
        {"LOWER":"lada","OP":"?"},
        {"LOWER":"mitsubishi","OP":"?"},
        {"LOWER":"nissan","OP":"?"},
        {"LOWER":"renault","OP":"?"},
        {"LOWER":"samsung","OP":"?"},
        {"LOWER":"venucia","OP":"?"},
        {"LOWER":"rivian","OP":"?"},
        {"LOWER":"im","OP":"?"},
        {"LOWER":"maxus","OP":"?"},
        {"LOWER":"mg","OP":"?"},
        {"LOWER":"roewe","OP":"?"},
        {"LOWER":"yuejin","OP":"?"},
        {"LOWER":"baojun","OP":"?"},
        {"LOWER":"wuling","OP":"?"},
        {"LOWER":"saipa","OP":"?"},
        {"LOWER":"zamyad","OP":"?"},
        {"LOWER":"shaanxi auto","OP":"?"},
        {"LOWER":"tangjun","OP":"?"},
        {"LOWER":"feidie auto","OP":"?"},
        {"LOWER":"srkc","OP":"?"},
        {"LOWER":"shaolin","OP":"?"},
        {"LOWER":"shuanghuan","OP":"?"},
        {"LOWER":"huanghai","OP":"?"},
        {"LOWER":"yema","OP":"?"},
        {"LOWER":"chuanlu","OP":"?"},
        {"LOWER":"dayun","OP":"?"},
        {"LOWER":"nanjun","OP":"?"},
        {"LOWER":"sinogold","OP":"?"},
        {"LOWER":"sitech","OP":"?"},
        {"LOWER":"uaz","OP":"?"},
        {"LOWER":"enovate","OP":"?"},
        {"LOWER":"soueast","OP":"?"},
        {"LOWER":"dearcc","OP":"?"},
        {"LOWER":"alfa romeo","OP":"?"},
        {"LOWER":"chrysler","OP":"?"},
        {"LOWER":"citroen","OP":"?"},
        {"LOWER":"dodge","OP":"?"},
        {"LOWER":"ds","OP":"?"},
        {"LOWER":"fiat","OP":"?"},
        {"LOWER":"jeep","OP":"?"},
        {"LOWER":"lancia","OP":"?"},
        {"LOWER":"maserati","OP":"?"},
        {"LOWER":"opel","OP":"?"},
        {"LOWER":"peugeot","OP":"?"},
        {"LOWER":"ram","OP":"?"},
        {"LOWER":"subaru","OP":"?"},
        {"LOWER":"suda","OP":"?"},
        {"LOWER":"sunlong","OP":"?"},
        {"LOWER":"maruti-suzuki","OP":"?"},
        {"LOWER":"suzuki","OP":"?"},
        {"LOWER":"jaguar","OP":"?"},
        {"LOWER":"land rover","OP":"?"},
        {"LOWER":"tata","OP":"?"},
        {"LOWER":"tesla","OP":"?"},
        {"LOWER":"togg","OP":"?"},
        {"LOWER":"daihatsu","OP":"?"},
        {"LOWER":"hino","OP":"?"},
        {"LOWER":"lexus","OP":"?"},
        {"LOWER":"toyota","OP":"?"},
        {"LOWER":"tvr","OP":"?"},
        {"LOWER":"vinfast","OP":"?"},
        {"LOWER":"audi","OP":"?"},
        {"LOWER":"bentley","OP":"?"},
        {"LOWER":"bugatti","OP":"?"},
        {"LOWER":"jetta","OP":"?"},
        {"LOWER":"lamborghini","OP":"?"},
        #{"LOWER":"man","OP":"?"},
        {"LOWER":"porsche","OP":"?"},
        #{"LOWER":"seat","OP":"?"},
        {"LOWER":"skoda","OP":"?"},
        {"LOWER":"volkswagen","OP":"?"},
        {"LOWER":"wanxiang","OP":"?"},
        {"LOWER":"yaxing","OP":"?"},
        {"LOWER":"yingzhi","OP":"?"},
        {"LOWER":"winnerway","OP":"?"},
        {"LOWER":"wm","OP":"?"},
        {"LOWER":"wzl","OP":"?"},
        {"LOWER":"xpeng","OP":"?"},
        {"LOWER":"youngman lotus","OP":"?"},
        {"LOWER":"luxgen","OP":"?"},
        {"LOWER":"yulu","OP":"?"},
        {"LOWER":"zedriv","OP":"?"},
        {"LOWER":"yutong","OP":"?"},
        {"LOWER":"zhongxing","OP":"?"},
        {"LOWER":"baic","OP":"?"},
        {"LOWER":"zoox","OP":"?"},
        {"LOWER":"jiangnan","OP":"?"},
        {"LOWER":"traum","OP":"?"},
        {"LOWER":"zotye","OP":"?"},
        {"LOWER":"agrale","OP":"?"},
        {"LOWER":"ankai auto","OP":"?"},
        {"LOWER":"arrival","OP":"?"},
        {"LOWER":"ashok leyland","OP":"?"},
        {"LOWER":"aston martin","OP":"?"},
        {"LOWER":"avtozaz","OP":"?"},
        {"LOWER":"baoneng motor","OP":"?"},
        {"LOWER":"bollore","OP":"?"},
        {"LOWER":"borgward","OP":"?"},
        {"LOWER":"canoo","OP":"?"},
        {"LOWER":"caterham","OP":"?"},
        {"LOWER":"ch-auto","OP":"?"},
        {"LOWER":"chengdu bus","OP":"?"},
        {"LOWER":"china first tractor","OP":"?"},
        {"LOWER":"china motor","OP":"?"},
        {"LOWER":"cnh industrial","OP":"?"},
        {"LOWER":"crrc","OP":"?"},
        {"LOWER":"deutsche post dhl group","OP":"?"},
        {"LOWER":"dorcen","OP":"?"},
        {"LOWER":"dreamedge","OP":"?"},
        {"LOWER":"eicher motor","OP":"?"},
        {"LOWER":"evergrande","OP":"?"},
        {"LOWER":"fdg","OP":"?"},
        {"LOWER":"ferrari","OP":"?"},
        {"LOWER":"fisker","OP":"?"},
        {"LOWER":"fmc","OP":"?"},
        {"LOWER":"foday","OP":"?"},
        {"LOWER":"fomm","OP":"?"},
        {"LOWER":"force motors","OP":"?"},
        {"LOWER":"frazer-nash","OP":"?"},
        {"LOWER":"fujian forta","OP":"?"},
        {"LOWER":"gaz","OP":"?"},
        {"LOWER":"glm","OP":"?"},
        {"LOWER":"green wheel ev","OP":"?"},
        {"LOWER":"guangtong auto","OP":"?"},
        {"LOWER":"guangzhou auto","OP":"?"},
        {"LOWER":"guilin bus","OP":"?"},
        {"LOWER":"hainan automobile","OP":"?"},
        {"LOWER":"hanteng auto","OP":"?"},
        {"LOWER":"hawtai","OP":"?"},
        {"LOWER":"hengtian","OP":"?"},
        {"LOWER":"hozon ev","OP":"?"},
        {"LOWER":"hubei sanhuan","OP":"?"},
        {"LOWER":"hubei sanjiang","OP":"?"},
        {"LOWER":"human horizon","OP":"?"},
        {"LOWER":"icm","OP":"?"},
        {"LOWER":"ineos","OP":"?"},
        {"LOWER":"isuzu","OP":"?"},
        {"LOWER":"jemmell","OP":"?"},
        {"LOWER":"jihai","OP":"?"},
        {"LOWER":"joylong","OP":"?"},
        {"LOWER":"karma automotive","OP":"?"},
        {"LOWER":"karsan","OP":"?"},
        {"LOWER":"leapmotor","OP":"?"},
        {"LOWER":"levdeo","OP":"?"},
        {"LOWER":"lifan","OP":"?"},
        {"LOWER":"linking auto","OP":"?"},
        {"LOWER":"linktour","OP":"?"},
        {"LOWER":"lixiang auto","OP":"?"},
        {"LOWER":"lordstown motors","OP":"?"},
        {"LOWER":"lucid motors","OP":"?"},
        {"LOWER":"marcopolo s.a.","OP":"?"},
        {"LOWER":"mazda","OP":"?"},
        {"LOWER":"mclaren","OP":"?"},
        {"LOWER":"morgan","OP":"?"},
        {"LOWER":"nami","OP":"?"},
        {"LOWER":"nio","OP":"?"},
        {"LOWER":"perodua","OP":"?"},
        {"LOWER":"piaggio","OP":"?"},
        {"LOWER":"premier","OP":"?"},
        {"LOWER":"proton","OP":"?"},
        {"LOWER":"qingling","OP":"?"},
        {"LOWER":"rivian automotive","OP":"?"},
        {"LOWER":"shaanxi auto","OP":"?"},
        {"LOWER":"shandong tangjun ouling","OP":"?"},
        {"LOWER":"shandong wuzheng","OP":"?"},
        {"LOWER":"shangrao coach","OP":"?"},
        {"LOWER":"shaolin bus","OP":"?"},
        {"LOWER":"shuanghuan","OP":"?"},
        {"LOWER":"shuguang","OP":"?"},
        {"LOWER":"sichuan yema","OP":"?"},
        {"LOWER":"sichuan-hyundai","OP":"?"},
        {"LOWER":"sinogold","OP":"?"},
        {"LOWER":"sitech","OP":"?"},
        {"LOWER":"sollers","OP":"?"},
        {"LOWER":"subaru","OP":"?"},
        {"LOWER":"suda","OP":"?"},
        {"LOWER":"sunlong bus","OP":"?"},
        {"LOWER":"tesla","OP":"?"},
        {"LOWER":"togg","OP":"?"},
        {"LOWER":"tvr","OP":"?"},
        {"LOWER":"vinfast","OP":"?"},
        {"LOWER":"wanxiang auto","OP":"?"},
        {"LOWER":"winnerway motors","OP":"?"},
        {"LOWER":"wm motor","OP":"?"},
        {"LOWER":"wzl motors","OP":"?"},
        {"LOWER":"xpeng ev","OP":"?"},
        {"LOWER":"youngman","OP":"?"},
        {"LOWER":"zedriv","OP":"?"},
        {"LOWER":"zhengzhou yutong","OP":"?"},
        {"LOWER":"zoox","OP":"?"},
        {"LOWER":"vw","OP":"?"},
        {"LOWER":"gm","OP":"?"}
    ]
    
    country_patterns = [
    {"LOWER":"afghanistan","OP":"?"},
    {"LOWER":"albania","OP":"?"},
    {"LOWER":"algeria","OP":"?"},
    {"LOWER":"andorra","OP":"?"},
    {"LOWER":"angola","OP":"?"},
    {"LOWER":"antigua and barbuda","OP":"?"},
    {"LOWER":"argentina","OP":"?"},
    {"LOWER":"armenia","OP":"?"},
    {"LOWER":"australia","OP":"?"},
    {"LOWER":"austria","OP":"?"},
    {"LOWER":"azerbaijan","OP":"?"},
    {"LOWER":"bahamas the","OP":"?"},
    {"LOWER":"bahrain","OP":"?"},
    {"LOWER":"bangladesh","OP":"?"},
    {"LOWER":"barbados","OP":"?"},
    {"LOWER":"belarus","OP":"?"},
    {"LOWER":"belgium","OP":"?"},
    {"LOWER":"belize","OP":"?"},
    {"LOWER":"benin","OP":"?"},
    {"LOWER":"bhutan","OP":"?"},
    {"LOWER":"bolivia","OP":"?"},
    {"LOWER":"bosnia and herzegovina","OP":"?"},
    {"LOWER":"botswana","OP":"?"},
    {"LOWER":"brazil","OP":"?"},
    {"LOWER":"brunei","OP":"?"},
    {"LOWER":"bulgaria","OP":"?"},
    {"LOWER":"burkina faso","OP":"?"},
    {"LOWER":"burundi","OP":"?"},
    {"LOWER":"cambodia","OP":"?"},
    {"LOWER":"cameroon","OP":"?"},
    {"LOWER":"canada","OP":"?"},
    {"LOWER":"cape verde","OP":"?"},
    {"LOWER":"central african republic","OP":"?"},
    {"LOWER":"chad","OP":"?"},
    {"LOWER":"chile","OP":"?"},
    {"LOWER":"china","OP":"?"},
    {"LOWER":"colombia","OP":"?"},
    {"LOWER":"comoros","OP":"?"},
    {"LOWER":"congo","OP":"?"},
    {"LOWER":"costa rica","OP":"?"},
    {"LOWER":"cote d'ivoire (ivory coast)","OP":"?"},
    {"LOWER":"croatia","OP":"?"},
    {"LOWER":"cuba","OP":"?"},
    {"LOWER":"cyprus","OP":"?"},
    {"LOWER":"czech republic","OP":"?"},
    {"LOWER":"democratic republic of the congo","OP":"?"},
    {"LOWER":"denmark","OP":"?"},
    {"LOWER":"djibouti","OP":"?"},
    {"LOWER":"dominica","OP":"?"},
    {"LOWER":"dominican republic","OP":"?"},
    {"LOWER":"east timor","OP":"?"},
    {"LOWER":"ecuador","OP":"?"},
    {"LOWER":"egypt","OP":"?"},
    {"LOWER":"el salvador","OP":"?"},
    {"LOWER":"equatorial guinea","OP":"?"},
    {"LOWER":"eritrea","OP":"?"},
    {"LOWER":"estonia","OP":"?"},
    {"LOWER":"ethiopia","OP":"?"},
    {"LOWER":"fiji islands","OP":"?"},
    {"LOWER":"finland","OP":"?"},
    {"LOWER":"france","OP":"?"},
    {"LOWER":"gabon","OP":"?"},
    {"LOWER":"gambia the","OP":"?"},
    {"LOWER":"georgia","OP":"?"},
    {"LOWER":"germany","OP":"?"},
    {"LOWER":"ghana","OP":"?"},
    {"LOWER":"greece","OP":"?"},
    {"LOWER":"grenada","OP":"?"},
    {"LOWER":"guatemala","OP":"?"},
    {"LOWER":"guinea","OP":"?"},
    {"LOWER":"guinea-bissau","OP":"?"},
    {"LOWER":"guyana","OP":"?"},
    {"LOWER":"haiti","OP":"?"},
    {"LOWER":"honduras","OP":"?"},
    {"LOWER":"hungary","OP":"?"},
    {"LOWER":"iceland","OP":"?"},
    {"LOWER":"india","OP":"?"},
    {"LOWER":"indonesia","OP":"?"},
    {"LOWER":"iran","OP":"?"},
    {"LOWER":"iraq","OP":"?"},
    {"LOWER":"ireland","OP":"?"},
    {"LOWER":"israel","OP":"?"},
    {"LOWER":"italy","OP":"?"},
    {"LOWER":"jamaica","OP":"?"},
    {"LOWER":"japan","OP":"?"},
    {"LOWER":"jordan","OP":"?"},
    {"LOWER":"kazakhstan","OP":"?"},
    {"LOWER":"kenya","OP":"?"},
    {"LOWER":"kiribati","OP":"?"},
    {"LOWER":"kuwait","OP":"?"},
    {"LOWER":"kyrgyzstan","OP":"?"},
    {"LOWER":"laos","OP":"?"},
    {"LOWER":"latvia","OP":"?"},
    {"LOWER":"lebanon","OP":"?"},
    {"LOWER":"lesotho","OP":"?"},
    {"LOWER":"liberia","OP":"?"},
    {"LOWER":"libya","OP":"?"},
    {"LOWER":"liechtenstein","OP":"?"},
    {"LOWER":"lithuania","OP":"?"},
    {"LOWER":"luxembourg","OP":"?"},
    {"LOWER":"macedonia","OP":"?"},
    {"LOWER":"madagascar","OP":"?"},
    {"LOWER":"malawi","OP":"?"},
    {"LOWER":"malaysia","OP":"?"},
    {"LOWER":"maldives","OP":"?"},
    {"LOWER":"mali","OP":"?"},
    {"LOWER":"malta","OP":"?"},
    {"LOWER":"mauritania","OP":"?"},
    {"LOWER":"mauritius","OP":"?"},
    {"LOWER":"mexico","OP":"?"},
    {"LOWER":"micronesia","OP":"?"},
    {"LOWER":"moldova","OP":"?"},
    {"LOWER":"mongolia","OP":"?"},
    {"LOWER":"montenegro","OP":"?"},
    {"LOWER":"morocco","OP":"?"},
    {"LOWER":"mozambique","OP":"?"},
    {"LOWER":"myanmar","OP":"?"},
    {"LOWER":"namibia","OP":"?"},
    {"LOWER":"nauru","OP":"?"},
    {"LOWER":"nepal","OP":"?"},
    {"LOWER":"netherlands","OP":"?"},
    {"LOWER":"new zealand","OP":"?"},
    {"LOWER":"nicaragua","OP":"?"},
    {"LOWER":"niger","OP":"?"},
    {"LOWER":"nigeria","OP":"?"},
    {"LOWER":"north korea","OP":"?"},
    {"LOWER":"norway","OP":"?"},
    {"LOWER":"oman","OP":"?"},
    {"LOWER":"pakistan","OP":"?"},
    {"LOWER":"palau","OP":"?"},
    {"LOWER":"panama","OP":"?"},
    {"LOWER":"papua new guinea","OP":"?"},
    {"LOWER":"paraguay","OP":"?"},
    {"LOWER":"peru","OP":"?"},
    {"LOWER":"philippines","OP":"?"},
    {"LOWER":"poland","OP":"?"},
    {"LOWER":"portugal","OP":"?"},
    {"LOWER":"qatar","OP":"?"},
    {"LOWER":"romania","OP":"?"},
    {"LOWER":"russia","OP":"?"},
    {"LOWER":"rwanda","OP":"?"},
    {"LOWER":"saint kitts and nevis","OP":"?"},
    {"LOWER":"saint lucia","OP":"?"},
    {"LOWER":"saint vincent and the grenadines","OP":"?"},
    {"LOWER":"samoa","OP":"?"},
    {"LOWER":"san marino","OP":"?"},
    {"LOWER":"sao tome and principe","OP":"?"},
    {"LOWER":"saudi arabia","OP":"?"},
    {"LOWER":"senegal","OP":"?"},
    {"LOWER":"serbia","OP":"?"},
    {"LOWER":"seychelles","OP":"?"},
    {"LOWER":"sierra leone","OP":"?"},
    {"LOWER":"singapore","OP":"?"},
    {"LOWER":"slovakia","OP":"?"},
    {"LOWER":"slovenia","OP":"?"},
    {"LOWER":"solomon islands","OP":"?"},
    {"LOWER":"somalia","OP":"?"},
    {"LOWER":"south africa","OP":"?"},
    {"LOWER":"south korea","OP":"?"},
    {"LOWER":"south sudan","OP":"?"},
    {"LOWER":"spain","OP":"?"},
    {"LOWER":"sri lanka","OP":"?"},
    {"LOWER":"sudan","OP":"?"},
    {"LOWER":"suriname","OP":"?"},
    {"LOWER":"swaziland","OP":"?"},
    {"LOWER":"sweden","OP":"?"},
    {"LOWER":"switzerland","OP":"?"},
    {"LOWER":"syria","OP":"?"},
    {"LOWER":"taiwan","OP":"?"},
    {"LOWER":"tajikistan","OP":"?"},
    {"LOWER":"tanzania","OP":"?"},
    {"LOWER":"thailand","OP":"?"},
    {"LOWER":"togo","OP":"?"},
    {"LOWER":"tonga","OP":"?"},
    {"LOWER":"trinidad and tobago","OP":"?"},
    {"LOWER":"tunisia","OP":"?"},
    {"LOWER":"turkey","OP":"?"},
    {"LOWER":"turkmenistan","OP":"?"},
    {"LOWER":"tuvalu","OP":"?"},
    {"LOWER":"uganda","OP":"?"},
    {"LOWER":"ukraine","OP":"?"},
    {"LOWER":"united arab emirates","OP":"?"},
    {"LOWER":"united kingdom","OP":"?"},
    {"LOWER":"united states","OP":"?"},
    {"LOWER":"uruguay","OP":"?"},
    {"LOWER":"uzbekistan","OP":"?"},
    {"LOWER":"vanuatu","OP":"?"},
    {"LOWER":"venezuela","OP":"?"},
    {"LOWER":"vietnam","OP":"?"},
    {"LOWER":"yemen","OP":"?"},
    {"LOWER":"zambia","OP":"?"},
    {"LOWER":"zimbabwe","OP":"?"}]
    
    matcher = Matcher(nlp.vocab)
    matcher.add("bmw", [brand_patterns])
    #dic = collections.defaultdict(list)
    dic = {}
    i = 0
    for text in data['title']:
        if text is None:
            dic[data['news_id'][i]] = ['No Organization']
        else:
            doc = nlp(text)
            matches = matcher(doc)
            brands = []
            for match in matches:
                brands.append(doc[match[1]:match[2]].text.lower())
            if len(brands) != 0:
                dic[data['news_id'][i]]=list(set(brands))
            else:
                dic[data['news_id'][i]] = ['No Organization']
        i = i + 1

    matcher = Matcher(nlp.vocab)
    matcher.add("brand", [brand_patterns])
    #dic = collections.defaultdict(list)
    dic_desc = {}
    i = 0
    for text in data['description']:
        if text is None:
            dic_desc[data['news_id'][i]] = dic_desc['No Organization']
        else:
            doc = nlp(text)
            matches = matcher(doc)
            brands = []
            for match in matches:
                brands.append(doc[match[1]:match[2]].text.lower())
            if len(brands) != 0:
                dic_desc[data['news_id'][i]]=list(set(brands))
            else:
                dic_desc[data['news_id'][i]] = ['No Organization']
        i = i + 1


    matcher = Matcher(nlp.vocab)
    matcher.add("con", [country_patterns])
    #dic = collections.defaultdict(list)
    dic_con = {}
    i = 0
    for text in data['title']:
        if text is None:
            dic_con[data['news_id'][i]] = ['No Country']
        else:
            doc = nlp(text)
            matches = matcher(doc)
            counntry = []
            for match in matches:
                counntry.append(doc[match[1]:match[2]].text.lower())
            if len(counntry) != 0:
                dic_con[data['news_id'][i]]=list(set(counntry))
            else:
                dic_con[data['news_id'][i]] = ['No Country']
        i = i + 1


    matcher = Matcher(nlp.vocab)
    matcher.add("con_desc", [country_patterns])
    #dic = collections.defaultdict(list)
    dic_con_desc = {}
    i = 0
    for text in data['description']:
        if text is None:
            dic_con_desc[data['news_id'][i]] = ['No Country']
        else:
            doc = nlp(text)
            matches = matcher(doc)
            counntry = []
            for match in matches:
                counntry.append(doc[match[1]:match[2]].text.lower())
            if len(counntry) != 0:
                dic_con_desc[data['news_id'][i]]=list(set(counntry))
            else:
                dic_con_desc[data['news_id'][i]] = ['No Country']
        i = i + 1
    
    
    company = {}
    for key in dic.keys():
        if dic[key] != ['No Organization']:
            company[key] = list(set(dic[key] + dic_desc[key]))
        else:
            company[key] = dic_desc[key]

    country = {}
    for key in dic_con.keys():
        if dic_con[key] != ['No Country']:
            country[key] = list(set(dic_con[key] + dic_con_desc[key]))
        else:
            country[key] = dic_con_desc[key]
            
    region = {}
    for key in country.keys():

        if 'No Country' in country[key]:
            if len(country[key])>1:
                country[key].remove('No Country')

        if country[key] == ['No Country']:
            region[key] = ['No Region']
        else:
            parent = []
            for i in country[key]:
                parent.append(location['region'][location['country_name'].str.lower() == i].item())
            region[key] = parent

    parent_company = {}
    for key in company.keys():

        if 'No Organization' in company[key]:
            if len(company[key])>1:
                company[key].remove('No Organization')

        if company[key] == ['No Organization']:
            parent_company[key] = ['No Customer']
        else:
            parent = []
            for i in company[key]:
                parent.append(master_brands['CUSTOMER GROUP'][master_brands['BRAND'].str.lower() == i].item())
            parent_company[key] = parent

    result = []
    dictionary = {}
    for key in country.keys():
        dictionary = {}
        dictionary['id'] = key
        dictionary['Country'] = country[key]
        dictionary['Customer_name'] = parent_company[key]
        dictionary['Location'] = ['No Location']
        dictionary['Region'] = region[key]
        dictionary['brand_name'] = company[key]
        result.append(dictionary)
    
    return result

# %%
location = pd.read_excel('country.xlsx')
master_brands = pd.read_csv('brands.csv')
data = pd.read_json('new data_v2.json')
outputfile = get_brand(data)

# %%
outputfile
